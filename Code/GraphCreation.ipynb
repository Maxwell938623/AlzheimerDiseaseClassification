# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Sample true labels and predicted labels (replace with your actual data)
y_true = np.array([])
y_pred = np.array([])

for i in range(32):
  y_true = np.append(y_true, 0)
for ii in range(22):
  y_true = np.append(y_true, 1)
for iii in range(8):
  y_true = np.append(y_true, 2)

for i in range(28):
  y_pred = np.append(y_pred, 0)
for i in range(4):
  y_pred = np.append(y_pred, 1)
for i in range(0):
  y_pred = np.append(y_pred, 2)

for i in range(7):
  y_pred = np.append(y_pred, 0)
for i in range(15):
  y_pred = np.append(y_pred, 1)
for i in range(0):
  y_pred = np.append(y_pred, 2)

for i in range(1):
  y_pred = np.append(y_pred, 0)
for ii in range(3):
  y_pred = np.append(y_pred, 1)
for iii in range(4):
  y_pred = np.append(y_pred, 2)

# Replace class_names with your custom class labels (if needed)
class_names = ['Non-Demented', 'Very Mild Demented', 'Mild Demented']

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, square=True, cbar_kws={"orientation": "vertical"})
plt.xlabel('Predicted Labels', fontsize=11, rotation=0, fontweight='bold')
plt.ylabel('True Labels', fontsize=11, fontweight='bold')
plt.title('Confusion Matrix Heatmap (Volume-based)', fontsize=14, fontweight='bold')

plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9, rotation=90)

plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Sample true labels and predicted labels (replace with your actual data)
y_true = np.array([])
y_pred = np.array([])

for i in range(55+74):
  y_true = np.append(y_true, 0)
for ii in range(61+58):
  y_true = np.append(y_true, 1)

for i in range(55):
  y_pred = np.append(y_pred, 0)
for i in range(74):
  y_pred = np.append(y_pred, 1)

for i in range(61):
  y_pred = np.append(y_pred, 0)
for i in range(58):
  y_pred = np.append(y_pred, 1)

# Replace class_names with your custom class labels (if needed)
class_names = ['Upward Trend', 'Downward Trend']

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 9/2))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, square=True, cbar_kws={"orientation": "vertical"})
plt.xlabel('Prediction', fontsize=11, rotation=0, fontweight='bold')
plt.ylabel('Actual Data', fontsize=11, fontweight='bold')
plt.title('Collective Dataset \n Confusion Matrix (Binary 1 Day Prediction)', fontsize=13, fontweight='bold')

plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9, rotation=90)

plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Sample true labels and predicted labels (replace with your actual data)
y_true = np.array([])
y_pred = np.array([])

for i in range(71):
  y_true = np.append(y_true, 0)
for ii in range(12):
  y_true = np.append(y_true, 1)
for iii in range(4):
  y_true = np.append(y_true, 2)

for i in range(68):
  y_pred = np.append(y_pred, 0)
for i in range(2):
  y_pred = np.append(y_pred, 1)
for i in range(1):
  y_pred = np.append(y_pred, 2)

for i in range(2):
  y_pred = np.append(y_pred, 0)
for i in range(10):
  y_pred = np.append(y_pred, 1)
for i in range(0):
  y_pred = np.append(y_pred, 2)

for i in range(1):
  y_pred = np.append(y_pred, 0)
for ii in range(0):
  y_pred = np.append(y_pred, 1)
for iii in range(3):
  y_pred = np.append(y_pred, 2)

# Replace class_names with your custom class labels (if needed)
class_names = ['Non-Demented', 'Very Mild Demented', 'Mild Demented']

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, square=True, cbar_kws={"orientation": "vertical"})
plt.xlabel('Predicted Labels', fontsize=11, rotation=0, fontweight='bold')
plt.ylabel('True Labels', fontsize=11, fontweight='bold')
plt.title('Confusion Matrix Heatmap (CNN Output)', fontsize=14, fontweight='bold')

plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9, rotation=90)

plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Sample true labels and predicted labels (replace with your actual data)
y_true = np.array([])
y_pred = np.array([])

for i in range(55):
  y_true = np.append(y_true, 0)
for ii in range(11):
  y_true = np.append(y_true, 1)

for i in range(75):
  y_pred = np.append(y_pred, 0)
for i in range(1):
  y_pred = np.append(y_pred, 1)

for i in range(0):
  y_pred = np.append(y_pred, 0)
for i in range(11):
  y_pred = np.append(y_pred, 1)

# Replace class_names with your custom class labels (if needed)
class_names = ['Non-Demented', 'Demented']

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 9/2))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, square=True, cbar_kws={"orientation": "vertical"})
plt.xlabel('Predicted Labels', fontsize=11, rotation=0, fontweight='bold')
plt.ylabel('True Labels', fontsize=11, fontweight='bold')
plt.title('Confusion Matrix Heatmap (CNN Output)', fontsize=14, fontweight='bold')

plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9, rotation=90)

plt.show()
